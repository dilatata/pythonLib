# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot
import seaborn as sns

# %%
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# # 전처리 Data

# %%
del titanic['alive']
del titanic['embarked']
del titanic['class']

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare    who  adult_male  \
# 0           0       3    male  22.0      1      0   7.2500    man        True
# 1           1       1  female  38.0      1      0  71.2833  woman       False
# 2           1       3  female  26.0      0      0   7.9250  woman       False
# 3           1       1  female  35.0      1      0  53.1000  woman       False
# 4           0       3    male  35.0      0      0   8.0500    man        True
# ..        ...     ...     ...   ...    ...    ...      ...    ...         ...
# 886         0       2    male  27.0      0      0  13.0000    man        True
# 887         1       1  female  19.0      0      0  30.0000  woman       False
# 888         0       3  female   NaN      1      2  23.4500  woman       False
# 889         1       1    male  26.0      0      0  30.0000    man        True
# 890         0       3    male  32.0      0      0   7.7500    man        True
#
#      embark_town  alone
# 0    Southampton  False
# 1      Cherbourg  False
# 2    Southampton   True
# 3    Southampton  False
# 4    Southampton   True
# ..           ...    ...
# 886  Southampton   True
# 887  Southampton   True
# 888  Southampton  False
# 889    Cherbourg   True
# 890   Queenstown   True
#
# [891 rows x 11 columns]

# %%
titanic['pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
titanic['who'].value_counts()
# Out:
# man      537
# woman    271
# child     83
# Name: who, dtype: int64

# %%
a1 = titanic['who']
a2 = titanic['sex']

p1 = (a1=='man')
p2 = (a1=='woman')
p3 = (a1=='child')

p1 = titanic[p1]['age'].median()
p2 = titanic[p2]['age'].median()
p3 = titanic[p3]['age'].median()

# %%
del titanic['deck']

# %%
t1 = titanic[titanic['who'] == 'man']
t1 = t1['age'].fillna(p1)
t1.isna().sum()
# Out:
# 0

# %%
t2 = titanic[titanic['who'] == 'woman']
t2 = t2['age'].fillna(p2)
t2.isna().sum()
# Out:
# 0

# %%
t3 = titanic[titanic['who'] == 'child']
t3 = t3['age'].fillna(p3)
t3.isna().sum()
# Out:
# 0

# %%
t_total = pd.concat([t1,t2,t3])
t_total = t_total.reset_index()
del t_total['index']
t_total.isna().sum()
t_total
# Out:
#        age
# 0    22.00
# 1    35.00
# 2    30.00
# 3    54.00
# 4    20.00
# ..     ...
# 886   0.83
# 887   4.00
# 888   9.00
# 889   4.00
# 890  15.00
#
# [891 rows x 1 columns]

# %%
q1 = (a1=='man')
q2 = (a1=='woman')
q3 = (a1=='child')
q1 = titanic[q1]

# %%
q2 = titanic[q2]

# %%
q3 = titanic[q3]

# %%
q_total = pd.concat([q1,q2,q3])
del q_total['age']
q_total
tot = pd.concat([q_total,t_total],axis=1)
tot
# Out:
#      survived  pclass     sex  sibsp  parch     fare    who  adult_male  \
# 0           0       3    male      1      0   7.2500    man        True
# 1           1       1  female      1      0  71.2833  woman       False
# 2           1       3  female      0      0   7.9250  woman       False
# 3           1       1  female      1      0  53.1000  woman       False
# 4           0       3    male      0      0   8.0500    man        True
# ..        ...     ...     ...    ...    ...      ...    ...         ...
# 886         0       2    male      0      0  13.0000    man        True
# 887         1       1  female      0      0  30.0000  woman       False
# 888         0       3  female      1      2  23.4500  woman       False
# 889         1       1    male      0      0  30.0000    man        True
# 890         0       3    male      0      0   7.7500    man        True
#
#      embark_town  alone    age
# 0    Southampton  False  22.00
# 1      Cherbourg  False  35.00
# 2    Southampton   True  30.00
# 3    Southampton  False  54.00
# 4    Southampton   True  20.00
# ..           ...    ...    ...
# 886  Southampton   True   0.83
# 887  Southampton   True   4.00
# 888  Southampton  False   9.00
# 889    Cherbourg   True   4.00
# 890   Queenstown   True  15.00
#
# [891 rows x 11 columns]

# %%
tot['embark_town'] = tot['embark_town'].fillna('unknown')
tot.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# sibsp          0
# parch          0
# fare           0
# who            0
# adult_male     0
# embark_town    0
# alone          0
# age            0
# dtype: int64

# %% [markdown]
# # Data 시각화

# %%
# 남성, 여성, 어린이 별 생존율

sns.catplot(x='who', y='survived', data=tot, kind='bar');

# %%
# 출발 도시별 생존율

sns.catplot(x='embark_town', y='survived', data=tot, kind='bar');

# %%
tot['age'].describe()
# Out:
# count    891.000000
# mean      29.758889
# std       13.002570
# min        0.420000
# 25%       22.000000
# 50%       30.000000
# 75%       35.000000
# max       80.000000
# Name: age, dtype: float64

# %%
tot['Age_cut'] = 0
# 0~16 / 16~32 / 32~48 / 48~64 / 64~80 구간으로 나누고 새 컬럼을 'A', 'B', 'C', 'D', 'E' 컬럼으로 만들기
tot['Age_cut'] = pd.cut(tot.age, bins=[0,10,20,30,40,50,60,80], labels=['0s','10s','20s','30s','40s','50s','60s~'])


# 구분 별 시각화하여 개수 확인하기
tot.Age_cut.value_counts().to_frame().style.background_gradient(cmap='summer')
# Out:
# <style  type="text/css" >
# #T_51a4ba2b_da41_11eb_9ff4_94e9798b1242row0_col0{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_51a4ba2b_da41_11eb_9ff4_94e9798b1242row1_col0{
#             background-color:  #58ac66;
#             color:  #000000;
#         }#T_51a4ba2b_da41_11eb_9ff4_94e9798b1242row2_col0{
#             background-color:  #3d9e66;
#             color:  #000000;
#         }#T_51a4ba2b_da41_11eb_9ff4_94e9798b1242row3_col0{
#             background-color:  #2a9466;
#             color:  #000000;
#         }#T_51a4ba2b_da41_11eb_9ff4_94e9798b1242row4_col0{
#             background-color:  #1b8d66;
#             color:  #000000;
#         }#T_51a4ba2b_da41_11eb_9ff4_94e9798b1242row5_col0{
#             background-color:  #0d8666;
#             color:  #000000;
#         }#T_51a4ba2b_da41_11eb_9ff4_94e9798b1242row6_col0{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_51a4ba2b_da41_11eb_9ff4_94e9798b1242" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Age_cut</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_51a4ba2b_da41_11eb_9ff4_94e9798b1242level0_row0" class="row_heading level0 row0" >20s</th>
#                         <td id="T_51a4ba2b_da41_11eb_9ff4_94e9798b1242row0_col0" class="data row0 col0" >407</td>
#             </tr>
#             <tr>
#                         <th id="T_51a4ba2b_da41_11eb_9ff4_94e9798b1242level0_row1" class="row_heading level0 row1" >30s</th>
#                         <td id="T_51a4ba2b_da41_11eb_9ff4_94e9798b1242row1_col0" class="data row1 col0" >155</td>
#             </tr>
#             <tr>
#                         <th id="T_51a4ba2b_da41_11eb_9ff4_94e9798b1242level0_row2" class="row_heading level0 row2" >10s</th>
#                         <td id="T_51a4ba2b_da41_11eb_9ff4_94e9798b1242row2_col0" class="data row2 col0" >115</td>
#             </tr>
#             <tr>
#                         <th id="T_51a4ba2b_da41_11eb_9ff4_94e9798b1242level0_row3" class="row_heading level0 row3" >40s</th>
#                         <td id="T_51a4ba2b_da41_11eb_9ff4_94e9798b1242row3_col0" class="data row3 col0" >86</td>
#             </tr>
#             <tr>
#                         <th id="T_51a4ba2b_da41_11eb_9ff4_94e9798b1242level0_row4" class="row_heading level0 row4" >0s</th>
#                         <td id="T_51a4ba2b_da41_11eb_9ff4_94e9798b1242row4_col0" class="data row4 col0" >64</td>
#             </tr>
#             <tr>
#                         <th id="T_51a4ba2b_da41_11eb_9ff4_94e9798b1242level0_row5" class="row_heading level0 row5" >50s</th>
#                         <td id="T_51a4ba2b_da41_11eb_9ff4_94e9798b1242row5_col0" class="data row5 col0" >42</td>
#             </tr>
#             <tr>
#                         <th id="T_51a4ba2b_da41_11eb_9ff4_94e9798b1242level0_row6" class="row_heading level0 row6" >60s~</th>
#                         <td id="T_51a4ba2b_da41_11eb_9ff4_94e9798b1242row6_col0" class="data row6 col0" >22</td>
#             </tr>
#     </tbody></table>

# %%
tot['Age_cut2'] = 0
# 0~16 / 16~32 / 32~48 / 48~64 / 64~80 구간으로 나누고 새 컬럼을 'A', 'B', 'C', 'D', 'E' 컬럼으로 만들기
tot['Age_cut2'] = pd.cut(tot.age, bins=[0,29,31,45,80], labels=['A', 'B', 'C', 'D'])


# 구분 별 시각화하여 개수 확인하기
tot.Age_cut2.value_counts().to_frame().style.background_gradient(cmap='summer')
# Out:
# <style  type="text/css" >
# #T_fb6a1b3d_da41_11eb_82a9_94e9798b1242row0_col0{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_fb6a1b3d_da41_11eb_82a9_94e9798b1242row1_col0{
#             background-color:  #6bb566;
#             color:  #000000;
#         }#T_fb6a1b3d_da41_11eb_82a9_94e9798b1242row2_col0{
#             background-color:  #48a366;
#             color:  #000000;
#         }#T_fb6a1b3d_da41_11eb_82a9_94e9798b1242row3_col0{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_fb6a1b3d_da41_11eb_82a9_94e9798b1242" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Age_cut2</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fb6a1b3d_da41_11eb_82a9_94e9798b1242level0_row0" class="row_heading level0 row0" >A</th>
#                         <td id="T_fb6a1b3d_da41_11eb_82a9_94e9798b1242row0_col0" class="data row0 col0" >384</td>
#             </tr>
#             <tr>
#                         <th id="T_fb6a1b3d_da41_11eb_82a9_94e9798b1242level0_row1" class="row_heading level0 row1" >B</th>
#                         <td id="T_fb6a1b3d_da41_11eb_82a9_94e9798b1242row1_col0" class="data row1 col0" >221</td>
#             </tr>
#             <tr>
#                         <th id="T_fb6a1b3d_da41_11eb_82a9_94e9798b1242level0_row2" class="row_heading level0 row2" >C</th>
#                         <td id="T_fb6a1b3d_da41_11eb_82a9_94e9798b1242row2_col0" class="data row2 col0" >183</td>
#             </tr>
#             <tr>
#                         <th id="T_fb6a1b3d_da41_11eb_82a9_94e9798b1242level0_row3" class="row_heading level0 row3" >D</th>
#                         <td id="T_fb6a1b3d_da41_11eb_82a9_94e9798b1242row3_col0" class="data row3 col0" >103</td>
#             </tr>
#     </tbody></table>

# %%
tot['age'].describe()
# Out:
# count    891.000000
# mean      29.758889
# std       13.002570
# min        0.420000
# 25%       22.000000
# 50%       30.000000
# 75%       35.000000
# max       80.000000
# Name: age, dtype: float64

# %%
# 나이대별 생존율

sns.catplot(x='Age_cut', y='survived', data=tot, kind='bar');

# %%
# 나이대별 생존율_2

sns.catplot(x='Age_cut2', y='survived', data=tot, kind='bar');

# %%
import seaborn as sns
sns.set_theme(style="white")

# Plot miles per gallon against horsepower with other semantics
sns.relplot(x="age", y="survived",size="Age_cut",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=tot);

# %%
tot_0 = tot[tot['survived'] == 0]
tot_1 = tot[tot['survived'] == 1]
tot_0
# Out:
#      survived  pclass     sex  sibsp  parch     fare    who  adult_male  \
# 0           0       3    male      1      0   7.2500    man        True
# 4           0       3    male      0      0   8.0500    man        True
# 5           0       3    male      0      0   8.4583    man        True
# 6           0       1    male      0      0  51.8625    man        True
# 7           0       3    male      3      1  21.0750  child       False
# ..        ...     ...     ...    ...    ...      ...    ...         ...
# 884         0       3    male      0      0   7.0500    man        True
# 885         0       3  female      0      5  29.1250  woman       False
# 886         0       2    male      0      0  13.0000    man        True
# 888         0       3  female      1      2  23.4500  woman       False
# 890         0       3    male      0      0   7.7500    man        True
#
#      embark_town  alone    age Age_cut Age_cut2
# 0    Southampton  False  22.00     20s        A
# 4    Southampton   True  20.00     10s        A
# 5     Queenstown   True  39.00     30s        C
# 6    Southampton   True  30.00     20s        B
# 7    Southampton  False  35.00     30s        C
# ..           ...    ...    ...     ...      ...
# 884  Southampton   True   1.00      0s        A
# 885   Queenstown  False  15.00     10s        A
# 886  Southampton   True   0.83      0s        A
# 888  Southampton  False   9.00      0s        A
# 890   Queenstown   True  15.00     10s        A
#
# [549 rows x 13 columns]

# %%
# 나이대별 생존자/사망자 분포

sns.set_style(style='ticks')
sns.kdeplot(data=tot, x="age", hue="survived");

# %%
# 나이대별 생존자/사망자 count

sns.histplot(data=tot, x="age", hue="survived", multiple="stack");

# %%
# 나이대별 사망자 수

sns.histplot(data=tot_0, x="age", hue="survived", multiple="stack");

# %%
# 나이대별 생존자 수

sns.histplot(data=tot_1, x="age", hue="survived", multiple="stack");

# %% [markdown]
# ## 전처리 연습용 Data

# %%
p2 = titanic['pclass']==2
p2 = titanic[p2]
p2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare    who  adult_male  \
# 9           1       2  female  14.0      1      0  30.0708  child       False
# 15          1       2  female  55.0      0      0  16.0000  woman       False
# 17          1       2    male   NaN      0      0  13.0000    man        True
# 20          0       2    male  35.0      0      0  26.0000    man        True
# 21          1       2    male  34.0      0      0  13.0000    man        True
# ..        ...     ...     ...   ...    ...    ...      ...    ...         ...
# 866         1       2  female  27.0      1      0  13.8583  woman       False
# 874         1       2  female  28.0      1      0  24.0000  woman       False
# 880         1       2  female  25.0      0      1  26.0000  woman       False
# 883         0       2    male  28.0      0      0  10.5000    man        True
# 886         0       2    male  27.0      0      0  13.0000    man        True
#
#      embark_town  alone
# 9      Cherbourg  False
# 15   Southampton   True
# 17   Southampton   True
# 20   Southampton   True
# 21   Southampton   True
# ..           ...    ...
# 866    Cherbourg  False
# 874    Cherbourg  False
# 880  Southampton  False
# 883  Southampton   True
# 886  Southampton   True
#
# [184 rows x 11 columns]

# %%
p3 = titanic['pclass']==3
p3 = titanic[p3]
p3
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare    who  adult_male  \
# 0           0       3    male  22.0      1      0   7.2500    man        True
# 2           1       3  female  26.0      0      0   7.9250  woman       False
# 4           0       3    male  35.0      0      0   8.0500    man        True
# 5           0       3    male   NaN      0      0   8.4583    man        True
# 7           0       3    male   2.0      3      1  21.0750  child       False
# ..        ...     ...     ...   ...    ...    ...      ...    ...         ...
# 882         0       3  female  22.0      0      0  10.5167  woman       False
# 884         0       3    male  25.0      0      0   7.0500    man        True
# 885         0       3  female  39.0      0      5  29.1250  woman       False
# 888         0       3  female   NaN      1      2  23.4500  woman       False
# 890         0       3    male  32.0      0      0   7.7500    man        True
#
#      embark_town  alone
# 0    Southampton  False
# 2    Southampton   True
# 4    Southampton   True
# 5     Queenstown   True
# 7    Southampton  False
# ..           ...    ...
# 882  Southampton   True
# 884  Southampton   True
# 885   Queenstown  False
# 888  Southampton  False
# 890   Queenstown   True
#
# [491 rows x 11 columns]

# %%
sns.set_style(style='ticks')
sns.kdeplot(data=titanic, x="age", hue="sex");
